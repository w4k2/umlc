# %% [markdown]
# Proszę załadować zbiór `credit_short.csv` i wykorzystać kolumnę "Class" jako etykiety, oraz "Amount" jako koszt. Proszę rozszerzyć Nearest Centroid aby uwzględniał koszt zbioru uczącego. Wykorzystaj koszt do obliczania `accuracy` / `balanced_accuracy`.
