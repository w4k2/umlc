# %%
from sklearn.datasets import make_classification
import matplotlib.pyplot as plt
import problexity as px
import numpy as np

X, y = make_classification(n_samples=1000, n_features=100, n_classes=2, flip_y=0.9, class_sep=10)
X.shape
# np.unique(y, return_counts=True)

fig = plt.figure()

plt.scatter(X[:, 0], X[:, 1], c=y)

# %%
cc = px.ComplexityCalculator()

# Fit model with data
cc.fit(X, y)


# Prepare figure
fig = plt.figure(figsize=(7,7))

# Generate plot describing the dataset
cc.plot(fig, (1,1,1))

# cc.complexity

# %% [markdown]
# 1. Wypisz parametry wygenerowanego zbioru danych (liczba cech, liczba klas, liczba cech kategorycznych, stopień niezbalansowania)
# 2. Wygeneruj różne zestawy danych. Sprawdź wpływ cech na różne wartości kalkulatora trudności problemu. Pamiętaj, że `make_classification` generuje różne zbiory danych, jeżeli nie zostanie przekazane ziarno losowości.
